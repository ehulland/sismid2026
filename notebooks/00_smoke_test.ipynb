# %% [markdown]
# # SISMID 2026 environment smoke test
#
# Run all cells. If you see **Environment OK** and a small plot, your Codespace is ready.

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib
import sklearn

print(f"Python {sys.version.split()[0]}")
for mod in (np, pd, matplotlib, sklearn):
    print(f"{mod.__name__:12s} {mod.__version__}")
# Out:
# Python 3.12.13
# numpy        2.5.1
# pandas       3.0.3
# matplotlib   3.11.1
# sklearn      1.9.0

# %%
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi, 100)
plt.figure(figsize=(5, 3))
plt.plot(x, np.sin(x))
plt.title("If you can see this curve, plotting works")
plt.tight_layout()
plt.show()

print("Environment OK")
# Out:
# Environment OK
